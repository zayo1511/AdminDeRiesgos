# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import seaborn as sns

# %%
St = yf.download(['PLTR', 'MELI'], start='2020-01-01')['Close'].dropna()
St
# Out:
# [*********************100%***********************]  2 of 2 completed
# Ticker             MELI       PLTR
# Date
# 2020-09-30  1082.479980   9.500000
# 2020-10-01  1115.339966   9.460000
# 2020-10-02  1079.329956   9.200000
# 2020-10-05  1090.579956   9.030000
# 2020-10-06  1091.390015   9.900000
# ...                 ...        ...
# 2025-01-13  1740.000000  64.980003
# 2025-01-14  1753.609985  65.910004
# 2025-01-15  1838.150024  68.139999
# 2025-01-16  1837.180054  69.239998
# 2025-01-17  1836.000000  71.769997
#
# [1081 rows x 2 columns]

# %%
plt.figure(figsize=(12,6))
plt.hist(St, label=St.columns, bins=50)
plt.legend()
plt.show()

# %%
rt = St.pct_change().dropna()

plt.figure(figsize=(12,6))
plt.hist(rt, label=rt.columns, bins=50)
plt.legend()
plt.show()

# %%
rt.mean()*252*100
# Out:
# Ticker
# MELI    26.209908
# PLTR    72.096566
# dtype: float64

# %%
rt.std()*252**(1/2)*100
# Out:
# Ticker
# MELI    52.652421
# PLTR    71.587855
# dtype: float64

# %%
rt.skew()
# Out:
# Ticker
# MELI   -0.006798
# PLTR    1.126382
# dtype: float64

# %%
rt.kurt()
# Out:
# Ticker
# MELI    3.092065
# PLTR    6.220677
# dtype: float64

# %%
sns.boxplot(rt)
# Out:
# <Axes: xlabel='Ticker'>
